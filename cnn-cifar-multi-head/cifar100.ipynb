# %% [markdown]
# # CIFAR-100 CNN  Multihead Classification
#
# Classificação de imagens do dataset [CIFAR 100](https://www.cs.toronto.edu/~kriz/cifar.html)
#
# A implementação tem como objetivo a criação de:
# - Modelo Single Head parametrizavel - Podendo escolher a quantidade de classes de saída
# - Modelo Multi Head - Contendo duas saídas - Fine para 100 classes e Coarse para 20 superclasses
#
# ## Metodologia
#
# A metodologia consiste em:
#
# 1. Análise do conjunto de dados
# 2. Leitura, Data Argumentation e divisão do conjunsto de dados entre treino, avaliação e teste.
# 3. Treinamento do modelo fine single head de 100 classes, análise do treinamento e resultado do teste.
# 4. Treinamento do modelo coarse single head de 20 super classes, análise do treinamento e resultado do teste.
# 5. Treinamento do modelo multi head análise do treinamento e resultado do teste.
# 6. Comparação e análise dos resultados.
#
#
# ### Detalhes de implementação
#
# - Foi utilizado o backbone [efficientnet_b0](https://docs.pytorch.org/vision/main/models/generated/torchvision.models.efficientnet_b0.html), com ~5.2M de parâmetros, é rápido e fácil de se utilizar, apresentando resultados satisfatórios como um todo neste modelo simples.
# - Otimizador `AdamW`.
# - O código apresenta um modo genérico de utilizar outros backbones presente na função `create_backbone`
# - Dados como `NUM_EPOCHS`, `BACKBONE_NAME`, `BATCH_SIZE`, `HIDDEN_DIM`, `DROPOUT` e etc estão parametrizados para todos os modelos, sendo possível intercambiar facilmente.
# - O código pode ser utilizado em CPU, GPU ou MPS (Macbooks) - Porém prioriza GPU.
# - O código utiliza early stop controlado pela constante `PATIENCE`
# - O report é enviado por mensagem ao telegram caso o usuário tenha configurado as variáveis ambiente `TELEGRAM_CHAT_ID` e `TELEGRAM_BOT_KEY`
# - Foi utilizada CrossEntropy
# - Os modelos com a menor loss na avaliação são salvos nos arquivos `best_coarse_model.pth`, `best_fine_model.pth` e `best_multihead_model.pth`
#
# ### Execução
#
# - Este código é executado em um servidor jupyter
# - Execute localmente utilizando o comando `./start_jupyter.sh`
# - Escolha o backbone utilizando `BACKBONE_NAME`
# - O report final parece nas ultima celulas com imagens da matriz de confusão e as curvas de acurácia e loss.

# %%
BACKBONE_NAME = "efficientnet_b0"
NUM_EPOCHS = 10
PATIENCE = 3

TRAIN_SPLIT_RATIO = 0.8

BATCH_SIZE = 128
LEARNING_RATE = 0.001  # Increased initial LR for scheduler to work better
WEIGHT_DECAY = 0.01  # Reduced to allow more learning capacity
NUM_WORKERS = 4

HIDDEN_DIM = 256
DROPOUT = 0.5

RANDOM_SEED = 42

# Scheduler parameters
USE_SCHEDULER = True
SCHEDULER_TYPE = "cosine_warm_restarts"  # Options: "cosine_warm_restarts", "reduce_on_plateau", "cosine"
SCHEDULER_T_MAX = 10  # For cosine_warm_restarts: period of restarts
SCHEDULER_ETA_MIN = 1e-6  # Minimum learning rate
SCHEDULER_FACTOR = 0.5  # For reduce_on_plateau: factor to reduce LR
SCHEDULER_PATIENCE = 5  # For reduce_on_plateau: epochs to wait before reducing

# %%
from torchvision.models import efficientnet_b0, mobilenet_v2, mobilenet_v3_small, shufflenet_v2_x0_5


def create_backbone():
    model_map = {
        "mobilenet_v2": mobilenet_v2(weights='IMAGENET1K_V2'),
        "mobilenet_v3_small": mobilenet_v3_small(weights='IMAGENET1K_V1'), # Did not work with this model
        "efficientnet_b0": efficientnet_b0(weights='IMAGENET1K_V1'),
        "shufflenet_v2_x0_5": shufflenet_v2_x0_5(weights='IMAGENET1K_V1')
    }

    return model_map[BACKBONE_NAME]

# %%
# Used to save images and send on telegram
final_report_loss_filepath = "final_report.png"
final_report_acc_filepath = "final_report_acc.png"

# %%
# Telegram Utils

import http.client
import json
import os
from datetime import datetime

chat_id = os.getenv("TELEGRAM_CHAT_ID")
bot_key = os.getenv("TELEGRAM_BOT_KEY")
telegram_url = f"/bot{bot_key}/sendMessage"

DISABLED_SEND_MESSAGE = chat_id is None or bot_key is None

def send_file(file_path, disable_notification=True):
    '''
    Used to send files to telegram
    '''

    if DISABLED_SEND_MESSAGE:
        return

    telegram_url = f"/bot{bot_key}/sendDocument"

    with open(file_path, 'rb') as file:
        file_data = file.read()

    boundary = 'boundary123'
    body = []

    body.append(f'--{boundary}'.encode())
    body.append(b'Content-Disposition: form-data; name="chat_id"')
    body.append(b'')
    body.append(chat_id.encode())

    body.append(f'--{boundary}'.encode())
    body.append(b'Content-Disposition: form-data; name="disable_notification"')
    body.append(b'')
    body.append(str(disable_notification).lower().encode())

    body.append(f'--{boundary}'.encode())
    body.append(f'Content-Disposition: form-data; name="document"; filename="{file_path}"'.encode())
    body.append(b'Content-Type: application/octet-stream')
    body.append(b'')
    body.append(file_data)

    body.append(f'--{boundary}--'.encode())
    body = b'\r\n'.join(body)

    conn = http.client.HTTPSConnection("api.telegram.org")
    headers = {
        'Content-Type': f'multipart/form-data; boundary={boundary}',
        'Content-Length': str(len(body))
    }

    conn.request("POST", telegram_url, body, headers)
    res = conn.getresponse()
    data = res.read().decode("utf-8")

    if res.status != 200:
        raise Exception(f"Error sending document: {data}")

    return data

def send_msg(message, disable_notification=True):
    '''
    Used to send messages to telegram
    '''

    if DISABLED_SEND_MESSAGE:
        return

    conn = http.client.HTTPSConnection("api.telegram.org")
    payload = json.dumps({
        "chat_id": chat_id,
        "text": f'{message}',
        "disable_notification": disable_notification
    })
    headers = {
        'Content-Type': 'application/json'
    }


    conn.request("POST", telegram_url, payload, headers)
    res = conn.getresponse()
    data = res.read().decode("utf-8")

    if res.status != 200:
        raise Exception(f"Error sending message: {data}")

    return data

# %%
send_msg(f"Started Model:{BACKBONE_NAME} with {NUM_EPOCHS} epochs\n At - {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}" )
# Out:
# '{"ok":true,"result":{"message_id":2873,"from":{"id":1720128152,"is_bot":true,"first_name":"Well Alerts \\ud83d\\udea8","username":"oliveiraswell_hpc_bot"},"chat":{"id":734929470,"first_name":"Wellington","last_name":"Oliveira","username":"oliveiraswell","type":"private"},"date":1764126725,"text":"Started Model:efficientnet_b0 with 10 epochs\\n At - 2025-11-25 23:12:04"}}'

# %%
def create_scheduler(optimizer, scheduler_type=SCHEDULER_TYPE, num_epochs=NUM_EPOCHS):
    """
    Create a learning rate scheduler based on the specified type.

    Args:
        optimizer: The optimizer to schedule
        scheduler_type: Type of scheduler ('cosine_warm_restarts', 'reduce_on_plateau', 'cosine')
        num_epochs: Total number of epochs

    Returns:
        Scheduler object or None if USE_SCHEDULER is False
    """
    if not USE_SCHEDULER:
        return None

    if scheduler_type == "cosine_warm_restarts":
        scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
            optimizer,
            T_0=SCHEDULER_T_MAX,
            T_mult=2,  # Multiplier for T_0 after each restart
            eta_min=SCHEDULER_ETA_MIN
        )
    elif scheduler_type == "reduce_on_plateau":
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            optimizer,
            mode='min',
            factor=SCHEDULER_FACTOR,
            patience=SCHEDULER_PATIENCE,
            min_lr=SCHEDULER_ETA_MIN,
            verbose=True
        )
    elif scheduler_type == "cosine":
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
            optimizer,
            T_max=num_epochs,
            eta_min=SCHEDULER_ETA_MIN
        )
    else:
        raise ValueError(f"Unknown scheduler type: {scheduler_type}")

    return scheduler

# %%
import re


class EarlyStopping:
    def __init__(self, patience=5, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = None
        self.early_stop = False
        self.best_epoch = 0

    def __call__(self, val_loss, epoch):
        if self.best_loss is None:
            self.best_loss = val_loss
            self.best_epoch = epoch
        elif val_loss > self.best_loss - self.min_delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_loss = val_loss
            self.best_epoch = epoch
            self.counter = 0

        return self.early_stop


class AutoSaveModel:
    def __init__(self):
        self.best_loss = None
        self.best_filename = None

    def should_save(self, val_loss):
        if self.best_loss is None or val_loss < self.best_loss:
            self.best_loss = val_loss
            return True
        return False

    def save(self, model, optimizer, epoch, train_loss, val_loss, filename, **kwargs):
        checkpoint = {
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'train_loss': train_loss,
            'val_loss': val_loss,
        }
        checkpoint.update(kwargs)

        base_name = re.sub(r'checkpoint_(.+?)_epoch_\d+\.pth', r'\1', filename)
        best_filename = f'best_{base_name}.pth'
        torch.save(checkpoint, best_filename)
        self.best_filename = best_filename


def load_best_model(model, filename, device):
    checkpoint = torch.load(filename, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'])
    return checkpoint

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
from torchinfo import summary
from torchvision.datasets import CIFAR100

# %%
train_dataset = CIFAR100(root='./data', train=True, download=True, transform=None)
test_dataset = CIFAR100(root='./data', train=False, download=True, transform=None)

for dataset, dataset_name in [[train_dataset, "train"], [test_dataset, "test"]]:
    print(f"Dataset {dataset_name} size: {len(dataset)}")
    print(f"Image shape: {dataset[0][0].size}")
    print(f"Number of classes: {len(dataset.classes)}")
    print("\n")
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Dataset train size: 50000
# Image shape: (32, 32)
# Number of classes: 100
#
#
# Dataset test size: 10000
# Image shape: (32, 32)
# Number of classes: 100

# %%
FINE_TO_COARSE_MAPPING = {
    4: 0, 30: 0, 55: 0, 72: 0, 95: 0,
    1: 1, 32: 1, 67: 1, 73: 1, 91: 1,
    54: 2, 62: 2, 70: 2, 82: 2, 92: 2,
    9: 3, 10: 3, 16: 3, 28: 3, 61: 3,
    0: 4, 51: 4, 53: 4, 57: 4, 83: 4,
    22: 5, 39: 5, 40: 5, 86: 5, 87: 5,
    5: 6, 20: 6, 25: 6, 84: 6, 94: 6,
    6: 7, 7: 7, 14: 7, 18: 7, 24: 7,
    3: 8, 42: 8, 43: 8, 88: 8, 97: 8,
    12: 9, 17: 9, 37: 9, 68: 9, 76: 9,
    23: 10, 33: 10, 49: 10, 60: 10, 71: 10,
    15: 11, 19: 11, 21: 11, 31: 11, 38: 11,
    34: 12, 63: 12, 64: 12, 66: 12, 75: 12,
    26: 13, 45: 13, 77: 13, 79: 13, 99: 13,
    2: 14, 11: 14, 35: 14, 46: 14, 98: 14,
    27: 15, 29: 15, 44: 15, 78: 15, 93: 15,
    36: 16, 50: 16, 65: 16, 74: 16, 80: 16,
    47: 17, 52: 17, 56: 17, 59: 17, 96: 17,
    8: 18, 13: 18, 48: 18, 58: 18, 90: 18,
    41: 19, 69: 19, 81: 19, 85: 19, 89: 19,
}

SUPERCLASS_NAMES = [
    'aquatic_mammals', 'fish', 'flowers', 'food_containers',
    'fruit_and_vegetables', 'household_electrical_devices', 'household_furniture',
    'insects', 'large_carnivores', 'large_man-made_outdoor_things',
    'large_natural_outdoor_scenes', 'large_omnivores_and_herbivores',
    'medium-sized_mammals', 'non-insect_invertebrates', 'people',
    'reptiles', 'small_mammals', 'trees', 'vehicles_1', 'vehicles_2'
]

print(f"Number of superclasses: {len(SUPERCLASS_NAMES)}")
print("\nSuperclass names:")
for idx, name in enumerate(SUPERCLASS_NAMES):
    print(f"{idx}: {name}")
# Out:
# Number of superclasses: 20
#
# Superclass names:
# 0: aquatic_mammals
# 1: fish
# 2: flowers
# 3: food_containers
# 4: fruit_and_vegetables
# 5: household_electrical_devices
# 6: household_furniture
# 7: insects
# 8: large_carnivores
# 9: large_man-made_outdoor_things
# 10: large_natural_outdoor_scenes
# 11: large_omnivores_and_herbivores
# 12: medium-sized_mammals
# 13: non-insect_invertebrates
# 14: people
# 15: reptiles
# 16: small_mammals
# 17: trees
# 18: vehicles_1
# 19: vehicles_2

# %%
fine_to_coarse_tensor = torch.zeros(100, dtype=torch.long)
for fine_id, coarse_id in FINE_TO_COARSE_MAPPING.items():
    fine_to_coarse_tensor[fine_id] = coarse_id

print(f"Shape: {fine_to_coarse_tensor.shape}")
print(f"Example mappings: {fine_to_coarse_tensor[:10]}")
# Out:
# Shape: torch.Size([100])
# Example mappings: tensor([ 4,  1, 14,  8,  0,  6,  7,  7, 18,  3])

# %%
from collections import Counter

superclass_counts = Counter()
for i in range(len(train_dataset)):
    _, fine_label = train_dataset[i]
    coarse_label = FINE_TO_COARSE_MAPPING[fine_label]
    superclass_counts[coarse_label] += 1

print("Distribution of superclasses in training set:")
print(f"Total samples: {sum(superclass_counts.values())}")

print("\nSamples per superclass:")
for superclass_id in sorted(superclass_counts.keys()):
    count = superclass_counts[superclass_id]
    print(f"{SUPERCLASS_NAMES[superclass_id]}: {count}")

plt.figure(figsize=(14, 6))
superclass_ids = sorted(superclass_counts.keys())
counts = [superclass_counts[i] for i in superclass_ids]
names = [SUPERCLASS_NAMES[i] for i in superclass_ids]

plt.bar(range(len(names)), counts)
plt.xticks(range(len(names)), names, rotation=45, ha='right')
plt.xlabel('Superclass')
plt.ylabel('Number of Samples')
plt.title('Distribution of Superclasses in Training Set')
plt.tight_layout()
plt.show()
# Out:
# Distribution of superclasses in training set:
# Total samples: 50000
#
# Samples per superclass:
# aquatic_mammals: 2500
# fish: 2500
# flowers: 2500
# food_containers: 2500
# fruit_and_vegetables: 2500
# household_electrical_devices: 2500
# household_furniture: 2500
# insects: 2500
# large_carnivores: 2500
# large_man-made_outdoor_things: 2500
# large_natural_outdoor_scenes: 2500
# large_omnivores_and_herbivores: 2500
# medium-sized_mammals: 2500
# non-insect_invertebrates: 2500
# people: 2500
# reptiles: 2500
# small_mammals: 2500
# trees: 2500
# vehicles_1: 2500
# vehicles_2: 2500

# %%
fig, axes = plt.subplots(4, 5, figsize=(15, 12))
fig.suptitle('Sample Images from Each Superclass', fontsize=16)

superclass_samples = {}
for i in range(len(train_dataset)):
    img, fine_label = train_dataset[i]
    coarse_label = FINE_TO_COARSE_MAPPING[fine_label]
    if coarse_label not in superclass_samples:
        superclass_samples[coarse_label] = i
    if len(superclass_samples) == 20:
        break

for superclass_id in range(20):
    if superclass_id in superclass_samples:
        idx = superclass_samples[superclass_id]
        img, _ = train_dataset[idx]

        row = superclass_id // 5
        col = superclass_id % 5
        ax = axes[row, col]
        ax.imshow(img)
        ax.set_title(SUPERCLASS_NAMES[superclass_id], fontsize=9)
        ax.axis('off')

plt.tight_layout()
plt.show()

# %%
import torch.nn as nn

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, Subset
from torchvision import transforms

transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5071, 0.4867, 0.4408], std=[0.2675, 0.2565, 0.2761]),
    transforms.RandomErasing(p=0.3, scale=(0.02, 0.2))
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5071, 0.4867, 0.4408], std=[0.2675, 0.2565, 0.2761])
])

full_train_dataset_raw = CIFAR100(root='./data', train=True, download=True, transform=None)
test_dataset_transformed = CIFAR100(root='./data', train=False, download=True, transform=transform_test)

train_labels = [full_train_dataset_raw[i][1] for i in range(len(full_train_dataset_raw))]

train_indices, val_indices = train_test_split(
    range(len(full_train_dataset_raw)),
    test_size=1 - TRAIN_SPLIT_RATIO,
    stratify=train_labels,
    random_state=RANDOM_SEED
)

full_train_dataset_with_aug = CIFAR100(root='./data', train=True, download=True, transform=transform_train)
full_train_dataset_no_aug = CIFAR100(root='./data', train=True, download=True, transform=transform_test)

train_dataset_transformed = Subset(full_train_dataset_with_aug, train_indices)
val_dataset_transformed = Subset(full_train_dataset_no_aug, val_indices)

print(f"Training samples: {len(train_dataset_transformed)}")
print(f"Validation samples: {len(val_dataset_transformed)}")
print(f"Test samples: {len(test_dataset_transformed)}")

train_loader = DataLoader(
    train_dataset_transformed,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=NUM_WORKERS
)
val_loader = DataLoader(
    val_dataset_transformed,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=NUM_WORKERS
)
test_loader = DataLoader(
    test_dataset_transformed,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=NUM_WORKERS
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Training samples: 40000
# Validation samples: 10000
# Test samples: 10000

# %%
from collections import Counter


def get_labels(dataset, transform_dataset=False):
    if transform_dataset:
        return [dataset[i][1] for i in range(len(dataset))]
    return [dataset[i][1] for i in range(len(dataset))]

train_labels = get_labels(train_dataset_transformed, transform_dataset=True)
val_labels = get_labels(val_dataset_transformed, transform_dataset=True)
test_labels = get_labels(test_dataset_transformed, transform_dataset=False)

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
fig.suptitle('Class Distribution Across Datasets', fontsize=16, y=1.02)

for idx, (labels, title, color) in enumerate([
    (train_labels, f'Train ({len(train_labels)} samples)', 'C0'),
    (val_labels, f'Validation ({len(val_labels)} samples)', 'C1'),
    (test_labels, f'Test ({len(test_labels)} samples)', 'C2')
]):
    class_counts = Counter(labels)
    sorted_counts = sorted(class_counts.items())
    class_ids, counts = zip(*sorted_counts)

    ax = axes[idx]
    ax.bar(range(len(class_ids)), counts, color=color, alpha=0.7)
    ax.set_xticks(range(0, 100, 10))
    ax.set_xlabel('Class ID')
    ax.set_ylabel('Number of Samples')
    ax.set_title(title)
    ax.grid(True, alpha=0.3, axis='y')

    print(f'{title}:')
    print(f'  Min samples: {min(counts)}, Max samples: {max(counts)}')
    print(f'  Std: {np.std(counts):.1f}')
    print()

plt.tight_layout()
plt.show()

train_coarse_dist = Counter([FINE_TO_COARSE_MAPPING[label] for label in train_labels])
val_coarse_dist = Counter([FINE_TO_COARSE_MAPPING[label] for label in val_labels])
test_coarse_dist = Counter([FINE_TO_COARSE_MAPPING[label] for label in test_labels])

fig, ax = plt.subplots(figsize=(14, 6))
x = np.arange(len(SUPERCLASS_NAMES))
width = 0.25

train_counts = [train_coarse_dist[i] for i in range(20)]
val_counts = [val_coarse_dist[i] for i in range(20)]
test_counts = [test_coarse_dist[i] for i in range(20)]

ax.bar(x - width, train_counts, width, label='Train', color='C0')
ax.bar(x, val_counts, width, label='Validation', color='C1')
ax.bar(x + width, test_counts, width, label='Test', color='C2')

ax.set_xlabel('Superclass')
ax.set_ylabel('Number of Samples')
ax.set_title('Superclass Distribution Across Datasets')
ax.set_xticks(x)
ax.set_xticklabels(SUPERCLASS_NAMES, rotation=45, ha='right')
ax.legend()
ax.grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.show()
# Out:
# Train (40000 samples):
#   Min samples: 400, Max samples: 400
#   Std: 0.0
#
# Validation (10000 samples):
#   Min samples: 100, Max samples: 100
#   Std: 0.0
#
# Test (10000 samples):
#   Min samples: 100, Max samples: 100
#   Std: 0.0

# %% [markdown]
# # Single Head models

# %%
class SingleHeadModel(nn.Module):
    def __init__(self, num_classes: int, hidden_dim: int = HIDDEN_DIM, dropout: float = DROPOUT):
        super().__init__()

        self.backbone = create_backbone()
        in_features = self.backbone.classifier[1].in_features

        self.backbone.classifier = nn.Sequential(
            nn.Linear(in_features, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, num_classes)
        )

    def forward(self, x):
        return self.backbone(x)

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
elif torch.backends.mps.is_available():
    device = torch.device('mps')
else:
    device = torch.device('cpu')

# %% [markdown]
# Single Head Fine - 100 classes

# %%
model = SingleHeadModel(num_classes=100)
summary(model, input_size=(1, 3, 32, 32))
# Out:
# ...
# Layer (type:depth-idx)                                       Output Shape              Param #
# ...
# SingleHeadModel                                              [1, 100]                  --
# ├─EfficientNet: 1-1                                          [1, 100]                  --
# │    └─Sequential: 2-1                                       [1, 1280, 1, 1]           --
# │    │    └─Conv2dNormActivation: 3-1                        [1, 32, 16, 16]           928
# │    │    └─Sequential: 3-2                                  [1, 16, 16, 16]           1,448
# │    │    └─Sequential: 3-3                                  [1, 24, 8, 8]             16,714
# │    │    └─Sequential: 3-4                                  [1, 40, 4, 4]             46,640
# │    │    └─Sequential: 3-5                                  [1, 80, 2, 2]             242,930
# │    │    └─Sequential: 3-6                                  [1, 112, 2, 2]            543,148
# ...

# %% [markdown]
# Training

# %%
history = {'train_loss': [], 'val_loss': []}
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
scheduler = create_scheduler(optimizer)
cross_entropy_loss = nn.CrossEntropyLoss()

model.to(device)
early_stopping = EarlyStopping(patience=PATIENCE)
autosave_model = AutoSaveModel()
print(f"Training Fine Model on {device}")
if scheduler:
    print(f"Using scheduler: {SCHEDULER_TYPE}")

for epoch in range(NUM_EPOCHS):
    model.train()
    epoch_loss = 0.0

    for data, target in train_loader:
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = cross_entropy_loss(output, target)
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()

    avg_train_loss = epoch_loss / len(train_loader)
    history['train_loss'].append(avg_train_loss)

    model.eval()
    val_loss = 0.0

    with torch.no_grad():
        for data, target in val_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            loss = cross_entropy_loss(output, target)
            val_loss += loss.item()

    avg_val_loss = val_loss / len(val_loader)
    history['val_loss'].append(avg_val_loss)

    # Update scheduler
    current_lr = optimizer.param_groups[0]['lr']
    if scheduler:
        if SCHEDULER_TYPE == "reduce_on_plateau":
            scheduler.step(avg_val_loss)
        else:
            scheduler.step()

    print("--------------------------------")
    print(f'Epoch {epoch+1}/{NUM_EPOCHS} - Train Loss: {avg_train_loss:.4f} - Val Loss: {avg_val_loss:.4f} - LR: {current_lr:.6f}')
    print("--------------------------------")

    if autosave_model.should_save(avg_val_loss):
        autosave_model.save(model, optimizer, epoch, avg_train_loss, avg_val_loss,
                           f'checkpoint_fine_model_epoch_{epoch+1}.pth')

    if early_stopping(avg_val_loss, epoch):
        print(f"Early stopping at epoch {epoch+1}")
        break
# Out:
# Training Fine Model on cuda
# Using scheduler: cosine_warm_restarts
# --------------------------------
# Epoch 1/10 - Train Loss: 3.8340 - Val Loss: 2.8497 - LR: 0.001000
# --------------------------------
# --------------------------------
# Epoch 2/10 - Train Loss: 2.9662 - Val Loss: 2.3883 - LR: 0.000976
# --------------------------------
# --------------------------------
# Epoch 3/10 - Train Loss: 2.6308 - Val Loss: 2.1239 - LR: 0.000905
# --------------------------------
# --------------------------------
# Epoch 4/10 - Train Loss: 2.4155 - Val Loss: 1.9976 - LR: 0.000794
# --------------------------------
# --------------------------------
# Epoch 5/10 - Train Loss: 2.2512 - Val Loss: 1.8611 - LR: 0.000655
# --------------------------------
# --------------------------------
# Epoch 6/10 - Train Loss: 2.1079 - Val Loss: 1.7641 - LR: 0.000501
# --------------------------------
# --------------------------------
# ...

# %%
def plot_training_history(history, title='Training and Validation Loss', figsize=(10, 5)):
    plt.figure(figsize=figsize)
    plt.plot(history['train_loss'], label='Train Loss', marker='o')
    plt.plot(history['val_loss'], label='Val Loss', marker='s')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(title)
    plt.xticks(range(len(history['train_loss'])))
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
from sklearn.metrics import classification_report

load_best_model(model, 'best_fine_model.pth', device)

model.eval()
test_loss = 0.0
all_preds = []
all_targets = []

with torch.no_grad():
    for data, target in test_loader:
        data, target = data.to(device), target.to(device)

        output = model(data)

        loss = cross_entropy_loss(output, target)
        test_loss += loss.item()

        pred = output.argmax(dim=1)
        all_preds.extend(pred.cpu().numpy())
        all_targets.extend(target.cpu().numpy())
# Out:
# /tmp/ipykernel_555164/235085351.py:56: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, map_location=device)

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix


def plot_confusion_matrix(y_true, y_pred, class_names, title='Confusion Matrix',
                          figsize=(16, 14), normalize=False, cmap='Blues'):
    cm = confusion_matrix(y_true, y_pred)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        fmt = '.2f'
        cbar_label = 'Proportion'
    else:
        fmt = 'd'
        cbar_label = 'Count'

    fig, ax = plt.subplots(figsize=figsize)

    sns.heatmap(cm, annot=True, fmt=fmt, cmap=cmap,
                xticklabels=class_names, yticklabels=class_names,
                cbar_kws={'label': cbar_label}, ax=ax,
                square=True, linewidths=0.5)

    ax.set_xlabel('Predicted Label', fontsize=12)
    ax.set_ylabel('True Label', fontsize=12)
    ax.set_title(title, fontsize=14, pad=20)

    plt.setp(ax.get_xticklabels(), rotation=45, ha='right', rotation_mode='anchor')
    plt.setp(ax.get_yticklabels(), rotation=0)

    plt.tight_layout()
    plt.show()

    return cm

# %%
plot_training_history(history, title='Training and Validation Loss - Fine Model (100 Classes)')

# %%
cm_fine = plot_confusion_matrix(
    y_true=all_targets,
    y_pred=all_preds,
    class_names=train_dataset.classes,
    title='Confusion Matrix - Fine Model (100 Classes)',
    figsize=(28, 26),
    normalize=False,
    cmap='Blues'
)

# %%
print(f"Test Loss: {test_loss / len(test_loader):.4f}\n")
print(classification_report(all_targets, all_preds))
# Out:
# Test Loss: 1.5771
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.77      0.79       100
#            1       0.60      0.79      0.68       100
#            2       0.39      0.36      0.37       100
#            3       0.25      0.18      0.21       100
#            4       0.24      0.17      0.20       100
#            5       0.49      0.73      0.58       100
#            6       0.53      0.66      0.59       100
#            7       0.57      0.61      0.59       100
#            8       0.76      0.66      0.71       100
#            9       0.68      0.71      0.69       100
#           10       0.51      0.47      0.49       100
#           11       0.37      0.28      0.32       100
#           12       0.68      0.65      0.66       100
#           13       0.43      0.28      0.34       100
#           14       0.53      0.60      0.56       100
#           15       0.42      0.49      0.45       100
# ...

# %% [markdown]
# ---
# # Model - Corse - 20 superclasses

# %%
model_coarse = SingleHeadModel(num_classes=20)
summary(model_coarse, input_size=(1, 3, 32, 32))
# Out:
# ...
# Layer (type:depth-idx)                                       Output Shape              Param #
# ...
# SingleHeadModel                                              [1, 20]                   --
# ├─EfficientNet: 1-1                                          [1, 20]                   --
# │    └─Sequential: 2-1                                       [1, 1280, 1, 1]           --
# │    │    └─Conv2dNormActivation: 3-1                        [1, 32, 16, 16]           928
# │    │    └─Sequential: 3-2                                  [1, 16, 16, 16]           1,448
# │    │    └─Sequential: 3-3                                  [1, 24, 8, 8]             16,714
# │    │    └─Sequential: 3-4                                  [1, 40, 4, 4]             46,640
# │    │    └─Sequential: 3-5                                  [1, 80, 2, 2]             242,930
# │    │    └─Sequential: 3-6                                  [1, 112, 2, 2]            543,148
# ...

# %% [markdown]
# Trainning - Coarse Model

# %%
history_coarse = {'train_loss': [], 'val_loss': []}
optimizer_coarse = torch.optim.AdamW(model_coarse.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
scheduler_coarse = create_scheduler(optimizer_coarse)
criterion_coarse = nn.CrossEntropyLoss()
num_epochs_coarse = NUM_EPOCHS

model_coarse.to(device)
fine_to_coarse_tensor_device = fine_to_coarse_tensor.to(device)
early_stopping_coarse = EarlyStopping(patience=PATIENCE)
autosave_model_coarse = AutoSaveModel()

print(f"Training coarse model (20 superclasses) on {device}")
if scheduler_coarse:
    print(f"Using scheduler: {SCHEDULER_TYPE}")

for epoch in range(num_epochs_coarse):
    model_coarse.train()
    epoch_loss = 0.0

    for data, target_fine in train_loader:
        data = data.to(device)
        target_fine = target_fine.to(device)

        target_coarse = fine_to_coarse_tensor_device[target_fine]

        optimizer_coarse.zero_grad()
        output = model_coarse(data)
        loss = criterion_coarse(output, target_coarse)
        loss.backward()
        optimizer_coarse.step()

        epoch_loss += loss.item()

    avg_train_loss = epoch_loss / len(train_loader)
    history_coarse['train_loss'].append(avg_train_loss)

    model_coarse.eval()
    val_loss = 0.0

    with torch.no_grad():
        for data, target_fine in val_loader:
            data = data.to(device)
            target_fine = target_fine.to(device)

            target_coarse = fine_to_coarse_tensor_device[target_fine]

            output = model_coarse(data)
            loss = criterion_coarse(output, target_coarse)
            val_loss += loss.item()

    avg_val_loss = val_loss / len(val_loader)
    history_coarse['val_loss'].append(avg_val_loss)

    # Update scheduler
    current_lr = optimizer_coarse.param_groups[0]['lr']
    if scheduler_coarse:
        if SCHEDULER_TYPE == "reduce_on_plateau":
            scheduler_coarse.step(avg_val_loss)
        else:
            scheduler_coarse.step()

    print("--------------------------------")
    print(f'Epoch {epoch+1}/{num_epochs_coarse} - Train Loss: {avg_train_loss:.4f} - Val Loss: {avg_val_loss:.4f} - LR: {current_lr:.6f}')
    print("--------------------------------")

    if autosave_model_coarse.should_save(avg_val_loss):
        autosave_model_coarse.save(model_coarse, optimizer_coarse, epoch, avg_train_loss, avg_val_loss,
                                   f'checkpoint_coarse_model_epoch_{epoch+1}.pth')

    if early_stopping_coarse(avg_val_loss, epoch):
        print(f"Early stopping at epoch {epoch+1}")
        break
# Out:
# Training coarse model (20 superclasses) on cuda
# Using scheduler: cosine_warm_restarts
# --------------------------------
# Epoch 1/10 - Train Loss: 2.3124 - Val Loss: 1.6911 - LR: 0.001000
# --------------------------------
# --------------------------------
# Epoch 2/10 - Train Loss: 1.8037 - Val Loss: 1.4104 - LR: 0.000976
# --------------------------------
# --------------------------------
# Epoch 3/10 - Train Loss: 1.6174 - Val Loss: 1.3086 - LR: 0.000905
# --------------------------------
# --------------------------------
# Epoch 4/10 - Train Loss: 1.4734 - Val Loss: 1.1909 - LR: 0.000794
# --------------------------------
# --------------------------------
# Epoch 5/10 - Train Loss: 1.3781 - Val Loss: 1.1169 - LR: 0.000655
# --------------------------------
# --------------------------------
# Epoch 6/10 - Train Loss: 1.2845 - Val Loss: 1.0744 - LR: 0.000501
# --------------------------------
# --------------------------------
# ...

# %%
load_best_model(model_coarse, 'best_coarse_model.pth', device)

model_coarse.eval()
test_loss_coarse = 0.0
all_preds_coarse = []
all_targets_coarse = []

with torch.no_grad():
    for data, target_fine in test_loader:
        data = data.to(device)
        target_fine = target_fine.to(device)

        target_coarse = fine_to_coarse_tensor_device[target_fine]

        output = model_coarse(data)
        loss = criterion_coarse(output, target_coarse)
        test_loss_coarse += loss.item()

        pred = output.argmax(dim=1)
        all_preds_coarse.extend(pred.cpu().numpy())
        all_targets_coarse.extend(target_coarse.cpu().numpy())
# Out:
# /tmp/ipykernel_555164/235085351.py:56: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, map_location=device)

# %%
plot_training_history(history_coarse, title='Training and Validation Loss - Coarse Model (20 Superclasses)')

# %%
cm_coarse = plot_confusion_matrix(
    y_true=all_targets_coarse,
    y_pred=all_preds_coarse,
    class_names=SUPERCLASS_NAMES,
    title='Confusion Matrix - Coarse Model (20 Superclasses)',
    figsize=(16, 14),
    normalize=False,
    cmap='Blues'
)

# %%
print(f"Test Loss (Coarse Model): {test_loss_coarse / len(test_loader):.4f}\n")
print("Classification Report - Coarse Model (20 Superclasses):")
print(classification_report(all_targets_coarse, all_preds_coarse, target_names=SUPERCLASS_NAMES))
# Out:
# Test Loss (Coarse Model): 0.9555
#
# Classification Report - Coarse Model (20 Superclasses):
#                                 precision    recall  f1-score   support
#
#                aquatic_mammals       0.57      0.54      0.55       500
#                           fish       0.71      0.62      0.66       500
#                        flowers       0.80      0.80      0.80       500
#                food_containers       0.79      0.76      0.77       500
#           fruit_and_vegetables       0.72      0.78      0.75       500
#   household_electrical_devices       0.69      0.72      0.70       500
#            household_furniture       0.80      0.78      0.79       500
#                        insects       0.62      0.76      0.68       500
#               large_carnivores       0.59      0.57      0.58       500
#  large_man-made_outdoor_things       0.80      0.82      0.81       500
#   large_natural_outdoor_scenes       0.88      0.83      0.85       500
# ...

# %% [markdown]
# ---
# # Multi Head Model

# %%
class MultiHeadModel(nn.Module):
    def __init__(self, num_classes_fine: int, num_classes_coarse: int,
                 hidden_dim: int = HIDDEN_DIM, dropout: float = DROPOUT):
        super().__init__()
        self.backbone = create_backbone()

        in_features = self.backbone.classifier[1].in_features
        self.backbone.classifier = nn.Identity()

        self.head_fine = nn.Sequential(
            nn.Linear(in_features, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, num_classes_fine)
        )

        self.head_coarse = nn.Sequential(
            nn.Linear(in_features, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, num_classes_coarse)
        )

    def forward(self, x):
        features = self.backbone(x)
        return self.head_fine(features), self.head_coarse(features)

# %%
model_multihead = MultiHeadModel(num_classes_fine=100, num_classes_coarse=20)
summary(model_multihead, input_size=(1, 3, 32, 32))
# Out:
# ...
# Layer (type:depth-idx)                                       Output Shape              Param #
# ...
# MultiHeadModel                                               [1, 100]                  --
# ├─EfficientNet: 1-1                                          [1, 1280]                 --
# │    └─Sequential: 2-1                                       [1, 1280, 1, 1]           --
# │    │    └─Conv2dNormActivation: 3-1                        [1, 32, 16, 16]           928
# │    │    └─Sequential: 3-2                                  [1, 16, 16, 16]           1,448
# │    │    └─Sequential: 3-3                                  [1, 24, 8, 8]             16,714
# │    │    └─Sequential: 3-4                                  [1, 40, 4, 4]             46,640
# │    │    └─Sequential: 3-5                                  [1, 80, 2, 2]             242,930
# │    │    └─Sequential: 3-6                                  [1, 112, 2, 2]            543,148
# ...

# %%
history_multihead = {'train_loss': [],
                     'train_loss_fine': [], 'train_loss_coarse': [],
                     'val_loss': [], 'val_loss_fine': [], 'val_loss_coarse': [],
                     'train_acc': [], 'train_acc_fine': [], 'train_acc_coarse': [],
                     'val_acc': [], 'val_acc_fine': [], 'val_acc_coarse': []}

optimizer_multihead = torch.optim.AdamW(model_multihead.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
scheduler_multihead = create_scheduler(optimizer_multihead)
criterion = nn.CrossEntropyLoss()

model_multihead.to(device)
fine_to_coarse_tensor_device = fine_to_coarse_tensor.to(device)
early_stopping_multihead = EarlyStopping(patience=PATIENCE)
autosave_model_multihead = AutoSaveModel()

print(f"Training multi-head model on {device}")
if scheduler_multihead:
    print(f"Using scheduler: {SCHEDULER_TYPE}")

for epoch in range(NUM_EPOCHS):
    model_multihead.train()
    epoch_loss_total = 0.0
    epoch_loss_fine = 0.0
    epoch_loss_coarse = 0.0
    correct_fine = 0
    correct_coarse = 0
    total_samples = 0

    for data, target_fine in train_loader:
        data = data.to(device)
        target_fine = target_fine.to(device)
        target_coarse = fine_to_coarse_tensor_device[target_fine]

        optimizer_multihead.zero_grad()
        output_fine, output_coarse = model_multihead(data)

        loss_fine = criterion(output_fine, target_fine)
        loss_coarse = criterion(output_coarse, target_coarse)
        loss_total = loss_fine + loss_coarse

        loss_total.backward()
        optimizer_multihead.step()

        epoch_loss_total += loss_total.item()
        epoch_loss_fine += loss_fine.item()
        epoch_loss_coarse += loss_coarse.item()

        pred_fine = output_fine.argmax(dim=1)
        pred_coarse = output_coarse.argmax(dim=1)
        correct_fine += (pred_fine == target_fine).sum().item()
        correct_coarse += (pred_coarse == target_coarse).sum().item()
        total_samples += target_fine.size(0)

    avg_train_loss = epoch_loss_total / len(train_loader)
    avg_train_loss_fine = epoch_loss_fine / len(train_loader)
    avg_train_loss_coarse = epoch_loss_coarse / len(train_loader)
    train_acc_fine = correct_fine / total_samples
    train_acc_coarse = correct_coarse / total_samples
    train_acc = (train_acc_fine + train_acc_coarse) / 2

    history_multihead['train_loss'].append(avg_train_loss)
    history_multihead['train_loss_fine'].append(avg_train_loss_fine)
    history_multihead['train_loss_coarse'].append(avg_train_loss_coarse)
    history_multihead['train_acc'].append(train_acc)
    history_multihead['train_acc_fine'].append(train_acc_fine)
    history_multihead['train_acc_coarse'].append(train_acc_coarse)

    model_multihead.eval()
    val_loss_total = 0.0
    val_loss_fine = 0.0
    val_loss_coarse = 0.0
    correct_fine_val = 0
    correct_coarse_val = 0
    total_samples_val = 0

    with torch.no_grad():
        for data, target_fine in val_loader:
            data = data.to(device)
            target_fine = target_fine.to(device)
            target_coarse = fine_to_coarse_tensor_device[target_fine]

            output_fine, output_coarse = model_multihead(data)

            loss_fine = criterion(output_fine, target_fine)
            loss_coarse = criterion(output_coarse, target_coarse)
            loss_total = loss_fine + loss_coarse

            val_loss_total += loss_total.item()
            val_loss_fine += loss_fine.item()
            val_loss_coarse += loss_coarse.item()

            pred_fine = output_fine.argmax(dim=1)
            pred_coarse = output_coarse.argmax(dim=1)
            correct_fine_val += (pred_fine == target_fine).sum().item()
            correct_coarse_val += (pred_coarse == target_coarse).sum().item()
            total_samples_val += target_fine.size(0)

    avg_val_loss = val_loss_total / len(val_loader)
    avg_val_loss_fine = val_loss_fine / len(val_loader)
    avg_val_loss_coarse = val_loss_coarse / len(val_loader)
    val_acc_fine = correct_fine_val / total_samples_val
    val_acc_coarse = correct_coarse_val / total_samples_val
    val_acc = (val_acc_fine + val_acc_coarse) / 2

    history_multihead['val_loss'].append(avg_val_loss)
    history_multihead['val_loss_fine'].append(avg_val_loss_fine)
    history_multihead['val_loss_coarse'].append(avg_val_loss_coarse)
    history_multihead['val_acc'].append(val_acc)
    history_multihead['val_acc_fine'].append(val_acc_fine)
    history_multihead['val_acc_coarse'].append(val_acc_coarse)

    # Update scheduler
    current_lr = optimizer_multihead.param_groups[0]['lr']
    if scheduler_multihead:
        if SCHEDULER_TYPE == "reduce_on_plateau":
            scheduler_multihead.step(avg_val_loss)
        else:
            scheduler_multihead.step()

    print("--------------------------------")
    print(f'Epoch {epoch+1}/{NUM_EPOCHS}')
    print(f'Train Loss: {avg_train_loss:.4f} (Fine: {avg_train_loss_fine:.4f}, Coarse: {avg_train_loss_coarse:.4f})')
    print(f'Val Loss: {avg_val_loss:.4f} (Fine: {avg_val_loss_fine:.4f}, Coarse: {avg_val_loss_coarse:.4f})')
    print(f'LR: {current_lr:.6f}')
    print("--------------------------------")

    if autosave_model_multihead.should_save(avg_val_loss):
        autosave_model_multihead.save(model_multihead, optimizer_multihead, epoch, avg_train_loss, avg_val_loss,
                                     f'checkpoint_multihead_model_epoch_{epoch+1}.pth',
                                     train_loss_fine=avg_train_loss_fine,
                                     train_loss_coarse=avg_train_loss_coarse,
                                     val_loss_fine=avg_val_loss_fine,
                                     val_loss_coarse=avg_val_loss_coarse)

    if early_stopping_multihead(avg_val_loss, epoch):
        print(f"Early stop - epoch {epoch+1}")
        break
# Out:
# Training multi-head model on cuda
# Using scheduler: cosine_warm_restarts
# --------------------------------
# Epoch 1/10
# Train Loss: 6.0437 (Fine: 3.7548, Coarse: 2.2889)
# Val Loss: 4.5301 (Fine: 2.8473, Coarse: 1.6828)
# LR: 0.001000
# --------------------------------
# --------------------------------
# Epoch 2/10
# Train Loss: 4.6677 (Fine: 2.9160, Coarse: 1.7517)
# Val Loss: 3.6900 (Fine: 2.3223, Coarse: 1.3677)
# LR: 0.000976
# --------------------------------
# --------------------------------
# Epoch 3/10
# Train Loss: 4.1539 (Fine: 2.5951, Coarse: 1.5589)
# Val Loss: 3.3407 (Fine: 2.1087, Coarse: 1.2320)
# LR: 0.000905
# --------------------------------
# --------------------------------
# Epoch 4/10
# Train Loss: 3.8176 (Fine: 2.3940, Coarse: 1.4236)
# Val Loss: 3.1160 (Fine: 1.9721, Coarse: 1.1439)
# LR: 0.000794
# --------------------------------
# --------------------------------
# Epoch 5/10
# Train Loss: 3.5326 (Fine: 2.2202, Coarse: 1.3124)
# ...

# %%
def plot_multihead_training_history(history, figsize=(18, 5)):
    fig, axes = plt.subplots(1, 3, figsize=figsize)

    axes[0].plot(history['train_loss'], label='Train', marker='o')
    axes[0].plot(history['val_loss'], label='Val', marker='s')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Loss')
    axes[0].set_title('Total Loss (Fine + Coarse)')
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)

    axes[1].plot(history['train_loss_fine'], label='Train', marker='o')
    axes[1].plot(history['val_loss_fine'], label='Val', marker='s')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Loss')
    axes[1].set_title('Fine Loss (100 classes)')
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)

    axes[2].plot(history['train_loss_coarse'], label='Train', marker='o')
    axes[2].plot(history['val_loss_coarse'], label='Val', marker='s')
    axes[2].set_xlabel('Epoch')
    axes[2].set_ylabel('Loss')
    axes[2].set_title('Coarse Loss (20 superclasses)')
    axes[2].legend()
    axes[2].grid(True, alpha=0.3)

    plt.tight_layout()
    fig.savefig(
        final_report_loss_filepath,
        dpi=300,
        bbox_inches='tight',
        pad_inches=0,
        format='png',
        transparent=False
    )
    plt.show()
    plt.close()

def plot_multihead_training_accuracy(history, figsize=(18, 5)):
    fig, axes = plt.subplots(1, 3, figsize=figsize)

    axes[0].plot(history['train_acc'], label='Train', marker='o')
    axes[0].plot(history['val_acc'], label='Val', marker='s')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Accuracy')
    axes[0].set_title('Total Accuracy (Fine + Coarse)')
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)

    axes[1].plot(history['train_acc_fine'], label='Train', marker='o')
    axes[1].plot(history['val_acc_fine'], label='Val', marker='s')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Accuracy')
    axes[1].set_title('Fine Accuracy (100 classes)')
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)

    axes[2].plot(history['train_acc_coarse'], label='Train', marker='o')
    axes[2].plot(history['val_acc_coarse'], label='Val', marker='s')
    axes[2].set_xlabel('Epoch')
    axes[2].set_ylabel('Accuracy')
    axes[2].set_title('Coarse Accuracy (20 superclasses)')
    axes[2].legend()
    axes[2].grid(True, alpha=0.3)

    plt.tight_layout()
    fig.savefig(
        final_report_acc_filepath,
        dpi=300,
        bbox_inches='tight',
        pad_inches=0,
        format='png',
        transparent=False
    )
    plt.show()
    plt.close()

# %%
load_best_model(model_multihead, 'best_multihead_model.pth', device)

model_multihead.eval()
test_loss_total = 0.0
test_loss_fine = 0.0
test_loss_coarse = 0.0
all_preds_fine_mh = []
all_targets_fine_mh = []
all_preds_coarse_mh = []
all_targets_coarse_mh = []

with torch.no_grad():
    for data, target_fine in test_loader:
        data = data.to(device)
        target_fine = target_fine.to(device)
        target_coarse = fine_to_coarse_tensor_device[target_fine]

        output_fine, output_coarse = model_multihead(data)

        loss_fine = criterion(output_fine, target_fine)
        loss_coarse = criterion(output_coarse, target_coarse)
        loss_total = loss_fine + loss_coarse

        test_loss_total += loss_total.item()
        test_loss_fine += loss_fine.item()
        test_loss_coarse += loss_coarse.item()

        pred_fine = output_fine.argmax(dim=1)
        pred_coarse = output_coarse.argmax(dim=1)

        all_preds_fine_mh.extend(pred_fine.cpu().numpy())
        all_targets_fine_mh.extend(target_fine.cpu().numpy())
        all_preds_coarse_mh.extend(pred_coarse.cpu().numpy())
        all_targets_coarse_mh.extend(target_coarse.cpu().numpy())
# Out:
# /tmp/ipykernel_555164/235085351.py:56: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, map_location=device)

# %%
plot_multihead_training_accuracy(history_multihead)
plot_multihead_training_history(history_multihead)

# %%
cm_fine_mh = plot_confusion_matrix(
    y_true=all_targets_fine_mh,
    y_pred=all_preds_fine_mh,
    class_names=train_dataset.classes,
    title='Confusion Matrix - Multi-Head Model (Fine Head - 100 Classes)',
    figsize=(28, 26),
    normalize=False,
    cmap='Blues'
)

# %%
cm_coarse_mh = plot_confusion_matrix(
    y_true=all_targets_coarse_mh,
    y_pred=all_preds_coarse_mh,
    class_names=SUPERCLASS_NAMES,
    title='Confusion Matrix - Multi-Head Model (Coarse Head - 20 Superclasses)',
    figsize=(16, 14),
    normalize=False,
    cmap='Blues'
)

# %%
print("Test Loss (Multi-Head Model):")
print(f"  Total: {test_loss_total / len(test_loader):.4f}")
print(f"  Fine: {test_loss_fine / len(test_loader):.4f}")
print(f"  Coarse: {test_loss_coarse / len(test_loader):.4f}")
# Out:
# Test Loss (Multi-Head Model):
#   Total: 2.4799
#   Fine: 1.5762
#   Coarse: 0.9037

# %%
print("--------------------------------")
print("CLASSIFICATION REPORT - MULTI-HEAD MODEL (FINE HEAD - 100 Classes)")
print("--------------------------------")
print(classification_report(all_targets_fine_mh, all_preds_fine_mh))

print("--------------------------------")
print("CLASSIFICATION REPORT - MULTI-HEAD MODEL (COARSE HEAD - 20 Superclasses)")
print("--------------------------------")
print(classification_report(all_targets_coarse_mh, all_preds_coarse_mh, target_names=SUPERCLASS_NAMES))
# Out:
# --------------------------------
# CLASSIFICATION REPORT - MULTI-HEAD MODEL (FINE HEAD - 100 Classes)
# --------------------------------
#               precision    recall  f1-score   support
#
#            0       0.77      0.72      0.74       100
#            1       0.63      0.79      0.70       100
#            2       0.38      0.31      0.34       100
#            3       0.26      0.21      0.23       100
#            4       0.30      0.21      0.25       100
#            5       0.45      0.63      0.53       100
#            6       0.55      0.59      0.57       100
#            7       0.62      0.58      0.60       100
#            8       0.80      0.64      0.71       100
#            9       0.66      0.67      0.67       100
#           10       0.51      0.42      0.46       100
#           11       0.39      0.30      0.34       100
#           12       0.69      0.57      0.62       100
#           13       0.42      0.28      0.34       100
# ...

# %%
def print_summary(name, report):
    print(f"\n{name}")
    print(f"  accuracy:     {report['accuracy']:.4f}")
    print(f"  macro avg:    p={report['macro avg']['precision']:.4f} r={report['macro avg']['recall']:.4f} f1={report['macro avg']['f1-score']:.4f}")
    print(f"  weighted avg: p={report['weighted avg']['precision']:.4f} r={report['weighted avg']['recall']:.4f} f1={report['weighted avg']['f1-score']:.4f}")

def append_summary_string(name, report):
    summary_string = f"\n{name}"
    summary_string += f"  accuracy:     {report['accuracy']:.4f}"
    summary_string += f"  macro avg:    p={report['macro avg']['precision']:.4f} r={report['macro avg']['recall']:.4f} f1={report['macro avg']['f1-score']:.4f}"
    summary_string += f"  weighted avg: p={report['weighted avg']['precision']:.4f} r={report['weighted avg']['recall']:.4f} f1={report['weighted avg']['f1-score']:.4f}"
    return summary_string

reports = [
    ("Fine Model (100 Classes)", all_targets, all_preds, None),
    ("Coarse Model (20 Superclasses)", all_targets_coarse, all_preds_coarse, SUPERCLASS_NAMES),
    ("Multi-Head Fine (100 Classes)", all_targets_fine_mh, all_preds_fine_mh, None),
    ("Multi-Head Coarse (20 Superclasses)", all_targets_coarse_mh, all_preds_coarse_mh, SUPERCLASS_NAMES),
]

print("-"*100)
print("Classification Report")
print("-"*100)

summaries = []
for name, y_true, y_pred, target_names in reports:
    report = classification_report(y_true, y_pred, target_names=target_names, output_dict=True)
    print_summary(name, report)
    summaries.append([name, report])
print("-"*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# Classification Report
# ----------------------------------------------------------------------------------------------------
#
# Fine Model (100 Classes)
#   accuracy:     0.5604
#   macro avg:    p=0.5558 r=0.5604 f1=0.5526
#   weighted avg: p=0.5558 r=0.5604 f1=0.5526
#
# Coarse Model (20 Superclasses)
#   accuracy:     0.6931
#   macro avg:    p=0.6923 r=0.6931 f1=0.6919
#   weighted avg: p=0.6923 r=0.6931 f1=0.6919
#
# Multi-Head Fine (100 Classes)
#   accuracy:     0.5548
#   macro avg:    p=0.5487 r=0.5548 f1=0.5471
#   weighted avg: p=0.5487 r=0.5548 f1=0.5471
#
# Multi-Head Coarse (20 Superclasses)
#   accuracy:     0.7065
#   macro avg:    p=0.7043 r=0.7065 f1=0.7045
#   weighted avg: p=0.7043 r=0.7065 f1=0.7045
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Best results
# ```
# Fine Model (100 Classes)
#   accuracy:     0.6182
#   macro avg:    p=0.6179 r=0.6182 f1=0.6157
#   weighted avg: p=0.6179 r=0.6182 f1=0.6157
#
# Coarse Model (20 Superclasses)
#   accuracy:     0.7303
#   macro avg:    p=0.7296 r=0.7303 f1=0.7294
#   weighted avg: p=0.7296 r=0.7303 f1=0.7294
#
# Multi-Head Fine (100 Classes)
#   accuracy:     0.6056
#   macro avg:    p=0.6037 r=0.6056 f1=0.6023
#   weighted avg: p=0.6037 r=0.6056 f1=0.6023
#
# Multi-Head Coarse (20 Superclasses)
#   accuracy:     0.7436
#   macro avg:    p=0.7427 r=0.7436 f1=0.7426
#   weighted avg: p=0.7427 r=0.7436 f1=0.7426
# ```

# %%
message_parts = []
message_parts.append("--------------Finished------------")
message_parts.append("--------------Validation----------")
message_parts.append("Model: " + BACKBONE_NAME)
message_parts.append("Epochs: " + str(NUM_EPOCHS))
message_parts.append("")
message_parts.append("At - " + datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
message_parts.append("------------Training--------------")
best_epoch = max(range(len(history_multihead['val_loss'])), key=lambda i: history_multihead['val_acc_fine'][i] + history_multihead['val_acc_coarse'][i])
message_parts.append(f"Best Epoch: {best_epoch + 1}")
message_parts.append(f"Best Val Acc Fine: {history_multihead['val_acc_fine'][best_epoch]:.4f}")
message_parts.append(f"Best Val Acc Coarse: {history_multihead['val_acc_coarse'][best_epoch]:.4f}")
message_parts.append("")
message_parts.append("------------Test--------------")

for name, report in summaries:
    message_parts.append(append_summary_string(name, report))

message_parts.append("")
message_parts.append("----------------------------------------")

send_msg("\n".join(message_parts))

send_file(final_report_loss_filepath)
send_file(final_report_acc_filepath)
# Out:
# '{"ok":true,"result":{"message_id":2876,"from":{"id":1720128152,"is_bot":true,"first_name":"Well Alerts \\ud83d\\udea8","username":"oliveiraswell_hpc_bot"},"chat":{"id":734929470,"first_name":"Wellington","last_name":"Oliveira","username":"oliveiraswell","type":"private"},"date":1764127213,"document":{"file_name":"final_report_acc.png","mime_type":"image/png","thumbnail":{"file_id":"AAMCAQADGQMAAgs8aSZx7dMc2dAu3z5VAkaI-_oi_A0AAtQFAAJLzTlFq8VhLXjBf-UBAAdtAAM2BA","file_unique_id":"AQAD1AUAAkvNOUVy","file_size":6632,"width":320,"height":85},"thumb":{"file_id":"AAMCAQADGQMAAgs8aSZx7dMc2dAu3z5VAkaI-_oi_A0AAtQFAAJLzTlFq8VhLXjBf-UBAAdtAAM2BA","file_unique_id":"AQAD1AUAAkvNOUVy","file_size":6632,"width":320,"height":85},"file_id":"BQACAgEAAxkDAAILPGkmce3THNnQLt8-VQJGiPv6IvwNAALUBQACS805RavFYS14wX_lNgQ","file_unique_id":"AgAD1AUAAkvNOUU","file_size":266771}}}'
